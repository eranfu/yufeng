# %%
import pandas as pd

pd.DataFrame([["p_2222", "u_dddd"]], columns=['p', 'u'])
# Out:
#         p       u
# 0  p_2222  u_dddd

# %%
df = pd.DataFrame({"苹果": [88, 99, 92], "香蕉": [70, 90, 95]}, index=['1月', '2月', '3月'])
df[df['香蕉'] > 90]
# Out:
#     苹果  香蕉
# 3月  92  95

# %%
df['香蕉'].sum()
# Out:
# np.int64(255)

# %%
df.sum()["香蕉"]
# Out:
# np.int64(255)

# %%
df['香蕉'].count()
# Out:
# np.int64(3)

# %%
df.count()
# Out:
# 苹果    3
# 香蕉    3
# dtype: int64
